# %% [markdown]
# ## Exercise 2: Data Exploration and Analysis

# %% [markdown]
# For this exercise we are going to use pandas library. You can find more information about pandas in the following link:https://pandas.pydata.org/
#
# The dataset for this exercise is from Kaggle called "Which Ketchup is Best?" meaning our goal is to answer the question using data science. You can download the dataset here: https://www.kaggle.com/datasets/ulrikthygepedersen/which-ketchup-is-best
#
# You can earn on this exercise in total 10 points. At the very end of this notebook, we provide a bonus question that could grant you an additional 1 point.
#
# The deadline to submit your solutions to this exercise is **next Tuesday (05.03.2024) by the end of the day (23:59 CET)**. Please submit your solutions in python notebook format (.ipynb).

# %% [markdown]
# Data exploration is a essential step in any data analysis. It helps to understand its underlying patterns, relationships and trents. This undestanding can help you to design appropriate models and techniques to analyze the data. Furthemore, you can comprehend the performance of any model easier if you have a full understanding of your dataset.

# %% [markdown]
# First and foremost, we import required libraries and load the dataset as follows:

# %%
#importing libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# enable inline plotting
# %matplotlib inline
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.

# %%
#load the data
data = pd.read_csv("data/Ketchup.csv", sep=',')

# %% [markdown]
# We can see the column "Unnamed:0" which is the indexing of entries. Since pandas also creates automatically indices, we can delete it as following:

# %%
del data["Unnamed: 0"]

# %%
data.head()
# Out:
#    Ketchup.hid  Ketchup.id Ketchup.choice  price.heinz  price.hunts  \
# 0            1           1          heinz         1.19         1.39
# 1            1           2          heinz         0.99         1.36
# 2            1           3          hunts         1.46         1.43
# 3            1           4          hunts         1.46         1.43
# 4            1           5            stb         1.46         1.36
#
#    price.delmonte  price.stb
# 0            1.49       0.89
# 1            1.39       0.95
# 2            1.49       0.99
# 3            1.45       0.99
# 4            1.39       0.95

# %%
data.tail()
# Out:
#       Ketchup.hid  Ketchup.id Ketchup.choice  price.heinz  price.hunts  \
# 4951         1952           1            stb         1.39         1.31
# 4952         1953           1          heinz         1.39         1.39
# 4953         1954           1            stb         1.39         1.43
# 4954         1955           1            stb         1.39         0.79
# 4955         1956           1            stb         1.39         1.39
#
#       price.delmonte  price.stb
# 4951            1.45       0.99
# 4952            0.99       0.79
# 4953            1.45       0.79
# 4954            1.45       0.79
# 4955            1.46       0.79

# %%
data.sample(10)
# Out:
#       Ketchup.hid  Ketchup.id Ketchup.choice  price.heinz  price.hunts  \
# 4080         1552           1          heinz         1.19         1.39
# 1098          406           6          heinz         1.46         1.29
# 1880          700           1          heinz         1.46         1.43
# 2680          997           2          heinz         1.46         1.29
# 1535          564           3          heinz         1.19         1.39
# 1560          573           3            stb         1.19         1.36
# 440           178           2          hunts         0.99         1.19
# 2247          838           4            stb         0.99         1.43
# 1718          628          14            stb         1.39         1.39
# 675           254           1          heinz         1.19         0.99
#
#       price.delmonte  price.stb
# 4080            1.49       0.89
# 1098            1.49       0.95
# 1880            1.49       0.99
# 2680            1.39       0.95
# 1535            1.49       0.89
# 1560            1.46       0.95
# 440             1.46       0.95
# 2247            1.49       0.99
# 1718            1.49       0.89
# 675             1.46       0.95

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4956 entries, 0 to 4955
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Ketchup.hid     4956 non-null   int64
#  1   Ketchup.id      4956 non-null   int64
#  2   Ketchup.choice  4956 non-null   object
#  3   price.heinz     4956 non-null   float64
#  4   price.hunts     4956 non-null   float64
#  5   price.delmonte  4956 non-null   float64
#  6   price.stb       4956 non-null   float64
# dtypes: float64(4), int64(2), object(1)
# memory usage: 271.2+ KB

# %%
data.iloc[0:3]
# Out:
#    Ketchup.hid  Ketchup.id Ketchup.choice  price.heinz  price.hunts  \
# 0            1           1          heinz         1.19         1.39
# 1            1           2          heinz         0.99         1.36
# 2            1           3          hunts         1.46         1.43
#
#    price.delmonte  price.stb
# 0            1.49       0.89
# 1            1.39       0.95
# 2            1.49       0.99

# %%
data["price.heinz"]
# Out:
# 0       1.19
# 1       0.99
# 2       1.46
# 3       1.46
# 4       1.46
#         ...
# 4951    1.39
# 4952    1.39
# 4953    1.39
# 4954    1.39
# 4955    1.39
# Name: price.heinz, Length: 4956, dtype: float64

# %%
#translating to numpy array
data["price.heinz"].to_numpy()
# Out:
# array([1.19, 0.99, 1.46, ..., 1.39, 1.39, 1.39])

# %%
data.describe()
# Out:
#        Ketchup.hid   Ketchup.id  price.heinz  price.hunts  price.delmonte  \
# count  4956.000000  4956.000000  4956.000000  4956.000000     4956.000000
# mean    936.721550     3.095642     1.248900     1.343860        1.426945
# std     549.104119     3.065865     0.204913     0.176185        0.114157
# min       1.000000     1.000000     0.790000     0.790000        0.890000
# 25%     463.750000     1.000000     0.990000     1.360000        1.390000
# 50%     923.000000     2.000000     1.190000     1.390000        1.460000
# 75%    1406.000000     4.000000     1.460000     1.430000        1.490000
# max    1956.000000    24.000000     1.470000     1.530000        1.490000
#
#          price.stb
# count  4956.000000
# mean      0.921178
# std       0.068198
# min       0.750000
# 25%       0.890000
# 50%       0.950000
# 75%       0.950000
# max       0.990000

# %% [markdown]
# We can notice from above that Ketchup.choice is not described since it is a categorical data.
#
# **Task 1 (1 point)**. Replace categories (heinz, stb, hunts and delmonte) with integers as 1,2,3,4 and print the description of the resultant dataset.

# %%
data['Ketchup.choice_categorical'] = data['Ketchup.choice']
mapping = {
    'heinz': 1,
    'stb': 2,
    'hunts': 3,
    'delmonte': 4
}
data['Ketchup.choice'] = data['Ketchup.choice'].map(mapping)

data.describe()
# Out:
#        Ketchup.hid   Ketchup.id  Ketchup.choice  price.heinz  price.hunts  \
# count  4956.000000  4956.000000     4956.000000  4956.000000  4956.000000
# mean    936.721550     3.095642        1.799233     1.248900     1.343860
# std     549.104119     3.065865        0.939033     0.204913     0.176185
# min       1.000000     1.000000        1.000000     0.790000     0.790000
# 25%     463.750000     1.000000        1.000000     0.990000     1.360000
# 50%     923.000000     2.000000        1.000000     1.190000     1.390000
# 75%    1406.000000     4.000000        3.000000     1.460000     1.430000
# max    1956.000000    24.000000        4.000000     1.470000     1.530000
#
#        price.delmonte    price.stb
# count     4956.000000  4956.000000
# mean         1.426945     0.921178
# std          0.114157     0.068198
# min          0.890000     0.750000
# 25%          1.390000     0.890000
# 50%          1.460000     0.950000
# 75%          1.490000     0.950000
# max          1.490000     0.990000

# %% [markdown]
# **Task 2 (1 point)**. Group the dataset according to Ketchup.choice and print its description. Which ketchup is leading from the number of entries?

# %%
grouped = data.groupby('Ketchup.choice')

max_entry = None
max_group = None

for name, group in grouped:
    print(f"group: {name}")
    print( group.describe())
    print("\n")

    #check
    if not max_entry:
        max_group = name
        max_entry = len(group)
    elif len(group) > max_entry:
        max_group = name
        max_entry = len(group)

# revers map
name_mapping = {v: k for k, v in mapping.items()}
print(f"Ketchup leading by number of entries: {name_mapping[max_group]} with {max_entry} entries.")
# Out:
# group: 1
#        Ketchup.hid   Ketchup.id  Ketchup.choice  price.heinz  price.hunts  \
# count  2526.000000  2526.000000          2526.0  2526.000000  2526.000000
# mean    928.501979     2.391528             1.0     1.166492     1.372419
# std     546.409356     2.361220             0.0     0.211237     0.140657
# min       1.000000     1.000000             1.0     0.790000     0.790000
# 25%     463.500000     1.000000             1.0     0.990000     1.360000
# 50%     912.500000     2.000000             1.0     1.190000     1.390000
# 75%    1385.000000     3.000000             1.0     1.390000     1.430000
# max    1953.000000    24.000000             1.0     1.470000     1.530000
#
#        price.delmonte    price.stb
# count     2526.000000  2526.000000
# mean         1.437549     0.931188
# std          0.093295     0.058649
# min          0.890000     0.750000
# 25%          1.390000     0.890000
# 50%          1.460000     0.950000
# 75%          1.490000     0.950000
# max          1.490000     0.990000
#
#
# group: 2
#        Ketchup.hid   Ketchup.id  Ketchup.choice  price.heinz  price.hunts  \
# count  1155.000000  1155.000000          1155.0  1155.000000  1155.000000
# mean    923.632900     4.451082             2.0     1.329186     1.382416
# std     550.308049     3.904402             0.0     0.159572     0.127497
# min       1.000000     1.000000             2.0     0.790000     0.790000
# 25%     450.500000     2.000000             2.0     1.190000     1.360000
# 50%     894.000000     3.000000             2.0     1.390000     1.390000
# 75%    1408.000000     6.000000             2.0     1.460000     1.430000
# max    1956.000000    22.000000             2.0     1.470000     1.530000
#
#        price.delmonte    price.stb
# count     1155.000000  1155.000000
# mean         1.443714     0.889048
# std          0.089064     0.080987
# min          0.890000     0.750000
# 25%          1.450000     0.790000
# 50%          1.470000     0.890000
# 75%          1.490000     0.950000
# max          1.490000     0.990000
#
#
# group: 3
#        Ketchup.hid   Ketchup.id  Ketchup.choice  price.heinz  price.hunts  \
# count  1019.000000  1019.000000          1019.0  1019.000000  1019.000000
# mean    969.874387     3.155054             3.0     1.342571     1.225417
# std     554.618956     2.847724             0.0     0.153065     0.243248
# min       1.000000     1.000000             3.0     0.790000     0.790000
# 25%     509.000000     1.000000             3.0     1.190000     0.890000
# 50%     972.000000     2.000000             3.0     1.390000     1.290000
# 75%    1463.000000     4.000000             3.0     1.460000     1.430000
# max    1950.000000    19.000000             3.0     1.470000     1.530000
#
#        price.delmonte    price.stb
# count     1019.000000  1019.000000
# mean         1.422169     0.930451
# std          0.099192     0.064093
# min          0.890000     0.750000
# 25%          1.390000     0.950000
# 50%          1.460000     0.950000
# 75%          1.490000     0.950000
# max          1.490000     0.990000
#
#
# group: 4
#        Ketchup.hid  Ketchup.id  Ketchup.choice  price.heinz  price.hunts  \
# count   256.000000  256.000000           256.0   256.000000   256.000000
# mean    944.914062    3.691406             4.0     1.326953     1.359570
# std     545.985571    3.531717             0.0     0.166321     0.162375
# min       6.000000    1.000000             4.0     0.990000     0.790000
# 25%     422.000000    1.000000             4.0     1.190000     1.382500
# 50%     994.000000    3.000000             4.0     1.390000     1.390000
# 75%    1387.500000    4.250000             4.0     1.460000     1.430000
# max    1948.000000   19.000000             4.0     1.470000     1.530000
#
#        price.delmonte   price.stb
# count      256.000000  256.000000
# mean         1.265664    0.930469
# std          0.251532    0.064301
# min          0.890000    0.750000
# 25%          0.990000    0.890000
# 50%          1.390000    0.950000
# 75%          1.490000    0.990000
# max          1.490000    0.990000
#
#
# Ketchup leading by number of entries: heinz with 2526 entries.

# %% [markdown]
# Plotting histograms of data helps us to understand the distrubiton and the trend.

# %%
data.hist(["price.heinz"])
data.hist([ "price.hunts"])
data.hist([ "price.stb"])
data.hist([ "price.delmonte"])
# Out:
# array([[<Axes: title={'center': 'price.delmonte'}>]], dtype=object)

# %% [markdown]
# **Task 3 (2 point)**. Plot the same histograms of each pricing column in the form of subplots (2x2) and set titles accordingly.

# %%
fig, axs = plt.subplots(2, 2, figsize=(12, 8))  #Create a 2x2 

data.hist("price.heinz", ax=axs[0, 0])
axs[0, 0].set_title("Price of Heinz")

data.hist("price.hunts", ax=axs[0, 1])
axs[0, 1].set_title("Price of Hunts")

data.hist("price.stb", ax=axs[1, 0])
axs[1, 0].set_title("Price of STB")

data.hist("price.delmonte", ax=axs[1, 1])
axs[1, 1].set_title("Price of Delmonte")

plt.show()

# %% [markdown]
# **Task 4 (2 points)**. Create a new column with chosen ketchup prices and name the column as price.choice. For example, if Ketchup.choice is heinz, then insert into a row of price.choice a corresponding value from price.heinz.

# %%
data.head()
# Out:
#    Ketchup.hid  Ketchup.id  Ketchup.choice  price.heinz  price.hunts  \
# 0            1           1               1         1.19         1.39
# 1            1           2               1         0.99         1.36
# 2            1           3               3         1.46         1.43
# 3            1           4               3         1.46         1.43
# 4            1           5               2         1.46         1.36
#
#    price.delmonte  price.stb Ketchup.choice_categorical
# 0            1.49       0.89                      heinz
# 1            1.39       0.95                      heinz
# 2            1.49       0.99                      hunts
# 3            1.45       0.99                      hunts
# 4            1.39       0.95                        stb

# %%
data['price.choice'] = data.apply(lambda row: row[f"price.{name_mapping[row['Ketchup.choice']]}"], axis=1)

data.head()
# Out:
#    Ketchup.hid  Ketchup.id  Ketchup.choice  price.heinz  price.hunts  \
# 0            1           1               1         1.19         1.39
# 1            1           2               1         0.99         1.36
# 2            1           3               3         1.46         1.43
# 3            1           4               3         1.46         1.43
# 4            1           5               2         1.46         1.36
#
#    price.delmonte  price.stb Ketchup.choice_categorical  price.choice
# 0            1.49       0.89                      heinz          1.19
# 1            1.39       0.95                      heinz          0.99
# 2            1.49       0.99                      hunts          1.43
# 3            1.45       0.99                      hunts          1.43
# 4            1.39       0.95                        stb          0.95

# %% [markdown]
# **Task 5 (2 points)**. Plot a normalized histogram of the price.choice with its kernel density estimate (kde) for the probability density function.

# %%
print(data['price.choice'])
# Out:
# 0       1.19
# 1       0.99
# 2       1.43
# 3       1.43
# 4       0.95
#         ...
# 4951    0.99
# 4952    1.39
# 4953    0.79
# 4954    0.79
# 4955    0.79
# Name: price.choice, Length: 4956, dtype: float64

# %%
# todo
sns.histplot(data['price.choice'], kde=True)
plt.title('Normalized Histogram with KDE of Price Choice')
plt.xlabel('Price Choice')
plt.ylabel('Density')

plt.show()

# %% [markdown]
# Thanks to the open-source nature of python, there are tons of libraries that can make our lives easier. Besides, matplotlib that we used in our previous tasks, there are other plotting libraries such as plotly. It's interactive and easy to use. You can find the documentation for it here:https://plotly.com/python/
#
# Also, you can install any library directly from your notebook as follows:
#
# %pip install plotly

# %%
import plotly.express as px

# %% [markdown]
# **Task 6 (1 point)**. Make a figure as boxplots of each ketchup.choice in terms of price.choice. You might need to search for boxplots from plotly documentation for that.

# %%
fig = px.box(data, x='Ketchup.choice_categorical', y='price.choice', title='Boxplot of Price Choice by Ketchup Choice')

fig.show()

# %% [markdown]
# Sometimes we play around with the data a lot and make too many changes to original data. Therefore, it is recommended to create the copy of the data and modify on it only.

# %%
datacopy = data.copy()
datacopy.drop(columns=['Ketchup.choice_categorical'], inplace=True)

# %% [markdown]
# **Task 7 (1 point)**.Estimate the correlation matrix in-between variables first.

# %%
corr = datacopy.corr(method='pearson') # used copy here as it was shown a cell earlier

# %% [markdown]
# Plotting the correlation matrix in the form of heat map helps to perceive the results easier.

# %%
plt.figure(figsize=(10,10))
ax = sns.heatmap(
    corr, 
    vmin=-1, vmax=1, center=0,
    cmap=sns.diverging_palette(20, 220, n=200),
    square=True, annot=True
)
ax.set_xticklabels(
    ax.get_xticklabels(),
    rotation=45,
    horizontalalignment='right'
)
ax.set_yticklabels(
    ax.get_yticklabels(),
    rotation=45,
);

# %% [markdown]
# **Task 8 (bonus point)**. What is your conclusion? Which ketchup is the best? Justify your answer.

# %% [markdown]
# Your response:

# %% [markdown]
# heinz, as is has the highest correlation with Ketchup.choice, suggesting a demand increase with an increase in price.
